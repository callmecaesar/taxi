# %%
import lightgbm as lgb
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /Users/zhaoliang/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
train = pd.read_csv('../data/train.csv')
label = pd.read_csv('../data/train_label.csv')
test = pd.read_csv('../data/test.csv')
submission = pd.read_csv('../data/submission.csv')
train_data = pd.merge(train,label,on='ID')

drop_feat = ['ID', '经营期限至', '经营期限自','成立日期','经营范围','邮政编码','核准日期','注销时间','Label']
feat = [item for item in train_data.columns if item not in drop_feat]
# Out:
# /Users/zhaoliang/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
X = train_data[feat]
y = train_data['Label'].values
x_train,x_test,y_train,y_test = train_test_split(X, y, test_size=0.3,random_state=42)

# %%
params = {'num_leaves': 60, #结果对最终效果影响较大，越大值越好，太大会出现过拟合
          'min_data_in_leaf': 30,
          'objective': 'binary', #定义的目标函数
          'max_depth': -1,
          'learning_rate': 0.03,
          "min_sum_hessian_in_leaf": 6,
          "is_unbalance": True,
          "boosting": "gbdt",
          "feature_fraction": 0.9,  #提取的特征比率
          "bagging_freq": 1,
          "bagging_fraction": 0.8,
          "bagging_seed": 11,
          "lambda_l1": 0.1,             #l1正则
          # 'lambda_l2': 0.001,     #l2正则
          "verbosity": -1,
          "nthread": -1,                #线程数量，-1表示全部线程，线程越多，运行的速度越快
          'metric': {'binary_logloss', 'auc'},  ##评价函数选择
          "random_state": 2019, #随机数种子，可以防止每次运行的结果不一致
          # 'device': 'gpu' ##如果安装的事gpu版本的lightgbm,可以加快运算
          }

# %%
trn_data = lgb.Dataset(x_train, label=y_train)
val_data = lgb.Dataset(x_test, label=y_test)

# %%
num_round = 1000
clf = lgb.train(params,
                    trn_data,
                    num_round,
                    valid_sets=[trn_data, val_data],
                    verbose_eval=20,
                    early_stopping_rounds=60)
# Out:
# Training until validation scores don't improve for 60 rounds.
# [20]	training's binary_logloss: 0.165998	training's auc: 0.965019	valid_1's binary_logloss: 0.173425	valid_1's auc: 0.919586
# [40]	training's binary_logloss: 0.168648	training's auc: 0.967365	valid_1's binary_logloss: 0.189735	valid_1's auc: 0.920359
# [60]	training's binary_logloss: 0.178294	training's auc: 0.96921	valid_1's binary_logloss: 0.209601	valid_1's auc: 0.920204
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.168524	training's auc: 0.963886	valid_1's binary_logloss: 0.172473	valid_1's auc: 0.918992

# %%
pd.set_option('max_rows', None)
feature_importance_df = pd.DataFrame()
feature_importance_df["Feature"] = feat
feature_importance_df["importance"] = clf.feature_importance()

# %%
feature_importance_df
# Out:
#              Feature  importance
# 0               企业类型          34
# 1               登记机关          39
# 2               企业状态           5
# 3               投资总额          20
# 4               注册资本          73
# 5               行业代码         115
# 6               行业门类          30
# 7               企业类别           2
# 8               管辖机关          30
# 9                增值税          76
# 10             企业所得税         106
# 11               印花税         131
# 12               教育费          66
# 13               城建税          62
# 14          递延收益_年初数           1
# 15        长期负债合计_年初数           0
# 16          长期借款_年初数           0
# 17         长期应付款_年初数           0
# 18          短期借款_年初数           0
# 19       递延所得税负债_年初数           0
# 20       非流动负债合计_年初数           0
# 21          负债合计_年初数           4
# 22    负债和所有者权益总计_年初数           1
# 23       交易性金融负债_年初数           0
# 24        流动负债合计_年初数           3
# 25       其他非流动负债_年初数           0
# 26   其他负债（或长期负债）_年初数           0
# 27        其他流动负债_年初数           0
# 28         其他应付款_年初数           5
# 29         其他应交款_年初数           0
# 30      实收资本（股本）_年初数           2
# 31   实收资本（或股本）净额_年初数           0
# 32       所有者权益合计_年初数           2
# 33         未分配利润_年初数           6
# 34      小企业_应付利润_年初数           0
# 35         应付福利费_年初数           0
# 36          应付股利_年初数           0
# 37          应付利息_年初数           0
# 38          应付票据_年初数           0
# 39        应付职工薪酬_年初数           0
# 40          应付债券_年初数           0
# 41          应付账款_年初数           0
# 42          预计负债_年初数           0
# 43          应交税费_年初数           2
# 44   一年内到期的非流动负债_年初数           0
# 45          预提费用_年初数           0
# 46          预收款项_年初数           3
# 47          盈余公积_年初数           0
# 48          资本公积_年初数           0
# 49         专项应付款_年初数           0
# 50          递延收益_年末数           0
# 51        长期负债合计_年末数           0
# 52          长期借款_年末数           1
# 53         长期应付款_年末数           0
# 54          短期借款_年末数           0
# 55       递延所得税负债_年末数           0
# 56       非流动负债合计_年末数           0
# 57          负债合计_年末数           2
# 58    负债和所有者权益总计_年末数           5
# 59       交易性金融负债_年末数           0
# 60        流动负债合计_年末数           0
# 61       其他非流动负债_年末数           0
# 62   其他负债（或长期负债）_年末数           0
# 63        其他流动负债_年末数           3
# 64         其他应付款_年末数           1
# 65         其他应交款_年末数           0
# 66      实收资本（股本）_年末数           0
# 67   实收资本（或股本）净额_年末数           0
# 68       所有者权益合计_年末数           4
# 69         未分配利润_年末数           0
# 70      小企业_应付利润_年末数           0
# 71         应付福利费_年末数           0
# 72          应付股利_年末数           0
# 73          应付利息_年末数           0
# 74          应付票据_年末数           0
# 75        应付职工薪酬_年末数           2
# 76          应付债券_年末数           0
# 77          应付账款_年末数           1
# 78          预计负债_年末数           0
# 79          应交税费_年末数           2
# 80   一年内到期的非流动负债_年末数           0
# 81          预提费用_年末数           0
# 82          预收款项_年末数           1
# 83          盈余公积_年末数           0
# 84          资本公积_年末数           1
# 85         专项应付款_年末数           0
# 86          货币资金_年初数          12
# 87            存货_年初数           3
# 88       存货中的原材料_年初数           0
# 89      存货中的周转材料_年初数           0
# 90        长期待摊费用_年初数           0
# 91        长期股权投资_年初数           0
# 92        长期投资合计_年初数           0
# 93         长期应收款_年初数           0
# 94       持有至到期投资_年初数           0
# 95          短期投资_年初数           0
# 96          待摊费用_年初数           0
# 97       递延所得税资产_年初数           0
# 98       非流动资产合计_年初数           4
# 99          工程物资_年初数           1
# 100       固定资产合计_年初数           1
# 101       固定资产净额_年初数           0
# 102       固定资产净值_年初数           0
# 103       固定资产清理_年初数           0
# 104       固定资产原价_年初数           0
# 105      交易性金融资产_年初数           0
# 106    库存商品(产成品)_年初数           0
# 107         开发支出_年初数           0
# 108     可供出售金融资产_年初数           0
# 109       流动资产合计_年初数           4
# 110      其他非流动资产_年初数           0
# 111       其他流动资产_年初数           0
# 112        其他应收款_年初数           4
# 113      生产性生物资产_年初数           0
# 114           商誉_年初数           0
# 115       投资性房地产_年初数           0
# 116         无形资产_年初数           1
# 117  无形资产及其他资产合计_年初数           0
# 118         应收账款_年初数           1
# 119  一年内到期的非流动资产_年初数           0
# 120         油气资产_年初数           0
# 121        应收补贴款_年初数           0
# 122         应收股利_年初数           0
# 123         应收利息_年初数           0
# 124         应收票据_年初数           2
# 125         预付款项_年初数           3
# 126         资产总计_年初数           0
# 127         在建工程_年初数           0
# 128         货币资金_年末数          12
# 129           存货_年末数           1
# 130      存货中的原材料_年末数           2
# 131     存货中的周转材料_年末数           0
# 132       长期待摊费用_年末数           0
# 133       长期股权投资_年末数           0
# 134       长期投资合计_年末数           0
# 135        长期应收款_年末数           0
# 136      持有至到期投资_年末数           0
# 137         短期投资_年末数           0
# 138         待摊费用_年末数           0
# 139      递延所得税资产_年末数           0
# 140      非流动资产合计_年末数           5
# 141         工程物资_年末数           0
# 142       固定资产合计_年末数           3
# 143       固定资产净额_年末数           0
# 144       固定资产净值_年末数           0
# 145       固定资产清理_年末数           0
# 146       固定资产原价_年末数           2
# 147      交易性金融资产_年末数           0
# 148    库存商品(产成品)_年末数           0
# 149         开发支出_年末数           0
# 150     可供出售金融资产_年末数           0
# 151       流动资产合计_年末数           3
# 152      其他非流动资产_年末数           0
# 153       其他流动资产_年末数           0
# 154        其他应收款_年末数           1
# 155      生产性生物资产_年末数           0
# 156           商誉_年末数           0
# 157       投资性房地产_年末数           0
# 158         无形资产_年末数           0
# 159  无形资产及其他资产合计_年末数           0
# 160         应收账款_年末数           1
# 161  一年内到期的非流动资产_年末数           0
# 162         油气资产_年末数           0
# 163        应收补贴款_年末数           0
# 164         应收股利_年末数           0
# 165         应收利息_年末数           0
# 166         应收票据_年末数           0
# 167         预付款项_年末数           6
# 168         资产总计_年末数           2
# 169         在建工程_年末数           1

# %%
prob_oof= clf.predict(x_test, num_iteration=clf.best_iteration)

# %%
# threshold = 0.4
# prob_oof = [1 if item > threshold else 0 for item in prob_oof ]

# %%
from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_test, prob_oof)
score
# Out:
# 0.9189918038732137

# %%
from collections import Counter
print(Counter(y_test))
print(Counter(prob_oof))
# Out:
# Counter({0: 4055, 1: 255})
# Counter({0: 4310})

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=2019)
prob_oof = np.zeros((train_x.shape[0], ))
test_pred_prob = np.zeros((test.shape[0], ))


## train and predict
feature_importance_df = pd.DataFrame()
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train)):
    print("fold {}".format(fold_ + 1))
    trn_data = lgb.Dataset(train_x.iloc[trn_idx], label=train_y[trn_idx])
    val_data = lgb.Dataset(train_x.iloc[val_idx], label=train_y[val_idx])


    clf = lgb.train(params,
                    trn_data,
                    num_round,
                    valid_sets=[trn_data, val_data],
                    verbose_eval=20,
                    early_stopping_rounds=60)
    prob_oof[val_idx] = clf.predict(train_x.iloc[val_idx], num_iteration=clf.best_iteration)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    test_pred_prob += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

threshold = 0.5
for pred in test_pred_prob:
    result = 1 if pred > threshold else 0

# %%
###cat

# %%
from catboost import CatBoostClassifier

# %%
def make_classifier():
    clf = CatBoostClassifier(
                               loss_function='Logloss',
                               eval_metric="AUC",
                               task_type="CPU",
                               learning_rate=0.01,
                               iterations=20000,
                               od_type="Iter",
        
#                                depth=8,
                               early_stopping_rounds=500,
    #                            l2_leaf_reg=1,
    #                            border_count=96,
                               random_seed=2019
                              )
        
    return clf

# %%
# x_train,x_test,y_train,y_test
drop_feat = ['ID', '经营期限至', '经营期限自','成立日期','经营范围','核准日期','注销时间','Label']
feat = [item for item in train_data.columns if item not in drop_feat]
cat_features=['邮政编码']
train_data[cat_features] = list(str(item) for item in train_data[cat_features])
X = train_data[feat]
y = train_data['Label'].values
x_train,x_test,y_train,y_test = train_test_split(X, y, test_size=0.3,random_state=42)


cat_clf = make_classifier()
cat_clf.fit(x_train, y_train, eval_set=(x_test, y_test),
            use_best_model=True, verbose=500, cat_features=cat_features)
# Out:
# 0:	test: 0.8481405	best: 0.8481405 (0)	total: 76.8ms	remaining: 25m 35s
# 500:	test: 0.9152603	best: 0.9152603 (500)	total: 7.03s	remaining: 4m 33s
# 1000:	test: 0.9180242	best: 0.9180242 (1000)	total: 14.5s	remaining: 4m 35s
# 1500:	test: 0.9198835	best: 0.9201349 (1433)	total: 21.9s	remaining: 4m 29s
# 2000:	test: 0.9195208	best: 0.9202611 (1647)	total: 28.8s	remaining: 4m 18s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.9202611155
# bestIteration = 1647
#
# Shrink model to first 1648 iterations.

# %%
from sklearn.metrics import roc_auc_score
prob_oof = cat_clf.predict_proba(x_test)
prob_oof = [item[1] for item in prob_oof]
score = roc_auc_score(y_test, prob_oof)
score
# Out:
# 0.920261115543628

# %%
pd.set_option('max_rows', None)
feature_importance_df = pd.DataFrame()
feature_importance_df["Feature"] = cat_clf.feature_names_
feature_importance_df["importance"] = cat_clf.feature_importances_

feature_importance_df
# Out:
#              Feature  importance
# 0               企业类型    1.755587
# 1               登记机关    1.895786
# 2               企业状态    0.729484
# 3               邮政编码    0.000000
# 4               投资总额    1.324455
# 5               注册资本    2.578459
# 6               行业代码    2.799386
# 7               行业门类    1.588462
# 8               企业类别    0.995954
# 9               管辖机关    2.306347
# 10               增值税   11.208441
# 11             企业所得税   19.629530
# 12               印花税    4.695427
# 13               教育费    5.650676
# 14               城建税    7.300239
# 15          递延收益_年初数    0.004971
# 16        长期负债合计_年初数    0.000000
# 17          长期借款_年初数    0.041349
# 18         长期应付款_年初数    0.045270
# 19          短期借款_年初数    0.130787
# 20       递延所得税负债_年初数    0.120100
# 21       非流动负债合计_年初数    0.091436
# 22          负债合计_年初数    0.425902
# 23    负债和所有者权益总计_年初数    0.369671
# 24       交易性金融负债_年初数    0.163069
# 25        流动负债合计_年初数    0.157974
# 26       其他非流动负债_年初数    0.005925
# 27   其他负债（或长期负债）_年初数    0.189711
# 28        其他流动负债_年初数    0.058430
# 29         其他应付款_年初数    0.481019
# 30         其他应交款_年初数    0.342271
# 31      实收资本（股本）_年初数    0.593288
# 32   实收资本（或股本）净额_年初数    0.090932
# 33       所有者权益合计_年初数    0.470451
# 34         未分配利润_年初数    0.428297
# 35      小企业_应付利润_年初数    0.060815
# 36         应付福利费_年初数    0.022339
# 37          应付股利_年初数    0.046494
# 38          应付利息_年初数    0.322289
# 39          应付票据_年初数    0.328187
# 40        应付职工薪酬_年初数    0.187614
# 41          应付债券_年初数    0.198598
# 42          应付账款_年初数    0.566223
# 43          预计负债_年初数    0.063568
# 44          应交税费_年初数    0.424932
# 45   一年内到期的非流动负债_年初数    0.035196
# 46          预提费用_年初数    0.069745
# 47          预收款项_年初数    0.214236
# 48          盈余公积_年初数    0.335363
# 49          资本公积_年初数    0.135015
# 50         专项应付款_年初数    0.033901
# 51          递延收益_年末数    0.034954
# 52        长期负债合计_年末数    0.186458
# 53          长期借款_年末数    0.046533
# 54         长期应付款_年末数    0.087973
# 55          短期借款_年末数    0.124179
# 56       递延所得税负债_年末数    0.045361
# 57       非流动负债合计_年末数    0.113990
# 58          负债合计_年末数    0.552152
# 59    负债和所有者权益总计_年末数    0.441002
# 60       交易性金融负债_年末数    0.377142
# 61        流动负债合计_年末数    0.348208
# 62       其他非流动负债_年末数    0.023273
# 63   其他负债（或长期负债）_年末数    0.000570
# 64        其他流动负债_年末数    0.151768
# 65         其他应付款_年末数    0.254030
# 66         其他应交款_年末数    0.012556
# 67      实收资本（股本）_年末数    0.404702
# 68   实收资本（或股本）净额_年末数    0.255587
# 69       所有者权益合计_年末数    0.520427
# 70         未分配利润_年末数    0.544840
# 71      小企业_应付利润_年末数    0.098477
# 72         应付福利费_年末数    0.015458
# 73          应付股利_年末数    0.218158
# 74          应付利息_年末数    0.034579
# 75          应付票据_年末数    0.073190
# 76        应付职工薪酬_年末数    0.387752
# 77          应付债券_年末数    0.428080
# 78          应付账款_年末数    0.329037
# 79          预计负债_年末数    0.012605
# 80          应交税费_年末数    0.763913
# 81   一年内到期的非流动负债_年末数    0.041138
# 82          预提费用_年末数    0.019113
# 83          预收款项_年末数    0.270154
# 84          盈余公积_年末数    0.384547
# 85          资本公积_年末数    0.071344
# 86         专项应付款_年末数    0.292064
# 87          货币资金_年初数    0.944476
# 88            存货_年初数    0.196983
# 89       存货中的原材料_年初数    0.055686
# 90      存货中的周转材料_年初数    0.068402
# 91        长期待摊费用_年初数    0.137389
# 92        长期股权投资_年初数    0.071635
# 93        长期投资合计_年初数    0.240016
# 94         长期应收款_年初数    0.020149
# 95       持有至到期投资_年初数    0.275812
# 96          短期投资_年初数    0.237214
# 97          待摊费用_年初数    0.069487
# 98       递延所得税资产_年初数    0.003225
# 99       非流动资产合计_年初数    0.323336
# 100         工程物资_年初数    0.171609
# 101       固定资产合计_年初数    0.438277
# 102       固定资产净额_年初数    0.104943
# 103       固定资产净值_年初数    0.460777
# 104       固定资产清理_年初数    0.298869
# 105       固定资产原价_年初数    0.239147
# 106      交易性金融资产_年初数    0.025836
# 107    库存商品(产成品)_年初数    0.087254
# 108         开发支出_年初数    0.047829
# 109     可供出售金融资产_年初数    0.048229
# 110       流动资产合计_年初数    0.901844
# 111      其他非流动资产_年初数    0.028441
# 112       其他流动资产_年初数    0.557872
# 113        其他应收款_年初数    0.973537
# 114      生产性生物资产_年初数    0.563146
# 115           商誉_年初数    0.362277
# 116       投资性房地产_年初数    0.039805
# 117         无形资产_年初数    0.270238
# 118  无形资产及其他资产合计_年初数    0.389451
# 119         应收账款_年初数    0.609316
# 120  一年内到期的非流动资产_年初数    0.142756
# 121         油气资产_年初数    0.256567
# 122        应收补贴款_年初数    0.040927
# 123         应收股利_年初数    0.521829
# 124         应收利息_年初数    0.005632
# 125         应收票据_年初数    0.097230
# 126         预付款项_年初数    0.508558
# 127         资产总计_年初数    0.495247
# 128         在建工程_年初数    0.080624
# 129         货币资金_年末数    1.317659
# 130           存货_年末数    0.267310
# 131      存货中的原材料_年末数    0.081750
# 132     存货中的周转材料_年末数    0.043676
# 133       长期待摊费用_年末数    0.203097
# 134       长期股权投资_年末数    0.082348
# 135       长期投资合计_年末数    0.240377
# 136        长期应收款_年末数    0.096734
# 137      持有至到期投资_年末数    0.111882
# 138         短期投资_年末数    0.008836
# 139         待摊费用_年末数    0.006569
# 140      递延所得税资产_年末数    0.016089
# 141      非流动资产合计_年末数    0.387891
# 142         工程物资_年末数    0.092182
# 143       固定资产合计_年末数    0.527321
# 144       固定资产净额_年末数    0.140411
# 145       固定资产净值_年末数    0.000000
# 146       固定资产清理_年末数    0.100300
# 147       固定资产原价_年末数    0.157268
# 148      交易性金融资产_年末数    0.021046
# 149    库存商品(产成品)_年末数    0.116240
# 150         开发支出_年末数    0.008947
# 151     可供出售金融资产_年末数    0.055762
# 152       流动资产合计_年末数    0.223764
# 153      其他非流动资产_年末数    0.125279
# 154       其他流动资产_年末数    0.146793
# 155        其他应收款_年末数    0.677055
# 156      生产性生物资产_年末数    0.037059
# 157           商誉_年末数    0.045881
# 158       投资性房地产_年末数    0.005181
# 159         无形资产_年末数    0.196303
# 160  无形资产及其他资产合计_年末数    0.517406
# 161         应收账款_年末数    0.570029
# 162  一年内到期的非流动资产_年末数    0.013825
# 163         油气资产_年末数    0.213530
# 164        应收补贴款_年末数    0.417561
# 165         应收股利_年末数    0.351041
# 166         应收利息_年末数    0.001768
# 167         应收票据_年末数    0.149812
# 168         预付款项_年末数    0.554193
# 169         资产总计_年末数    0.407566
# 170         在建工程_年末数    0.171467
